# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

# %%
df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/providers.parquet')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE',
)

write_pandas(conn, df, "providers", auto_create_table=True, quote_identifiers= False)
# Out:
# (True,
#  1,
#  4777,
#  [('snowpark_temp_stage_1npxs6kff9/file0.txt',
#    'LOADED',
#    4777,
#    4777,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None)])

# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/emergency_contacts.parquet')

conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE'
)

write_pandas(conn, df, 'emergency_contacts', auto_create_table=True)
# Out:
# (True,
#  1,
#  115063,
#  [('snowpark_temp_stage_z1cllisene/file0.txt',
#    'LOADED',
#    115063,
#    115063,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None)])

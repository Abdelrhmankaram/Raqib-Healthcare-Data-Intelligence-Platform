# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

# %%
df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/transfers.parquet')

conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE'
)

write_pandas(conn, df, 'transfers', auto_create_table=True, quote_identifiers=False)

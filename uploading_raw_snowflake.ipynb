# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

# %%
df = pd.read_parquet('Data/fda_downloads/drugs_data_cleaned_v2.parquet')

conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE'
)

write_pandas(conn, df, 'drugs', auto_create_table=True, quote_identifiers=False)
# Out:
# (True,
#  1,
#  39629,
#  [('snowpark_temp_stage_2a0pb9wkbg/file0.txt',
#    'LOADED',
#    39629,
#    39629,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None)])

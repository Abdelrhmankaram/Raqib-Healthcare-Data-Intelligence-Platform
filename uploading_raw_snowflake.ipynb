# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

# %%
df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/providers.parquet')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE',
)

write_pandas(conn, df, "providers", quote_identifiers= False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 13
#       1 df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/providers.parquet')
#       3 conn = snowflake.connector.connect(
#       4     account='OFNFMZZ-WH33726',
#       5     user='YOUSSEF',
#    (...)
#      10     role='RAQIB_ROLE',
#      11 )
# ---> 13 write_pandas(conn, df, "providers", quote_identifiers= False)
#
# File ~/.local/lib/python3.10/site-packages/snowflake/connector/pandas_tools.py:602, in write_pandas(conn, df, table_name, database, schema, chunk_size, compression, on_error, parallel, quote_identifiers, infer_schema, auto_create_table, create_temp_table, overwrite, table_type, use_logical_type, iceberg_config, bulk_upload_chunks, use_vectorized_scanner, **kwargs)
#     597 params = (
#     598     target_table_location,
#     599     on_error,
#     600 )
#     601 logger.debug(f"copying into with '{copy_into_sql}'. params: %s", params)
# --> 602 copy_results = cursor.execute(
#     603     copy_into_sql,
#     604     _is_internal=True,
#     605     _force_qmark_paramstyle=True,
#     606     params=params,
#     607     num_statements=1,
#     608 ).fetchall()
#     610 if overwrite and auto_create_table:
#     611     original_table_location = build_location_helper(
#     612         database=database,
#     613         schema=schema,
#     614         name=table_name,
#     615         quote_identifiers=quote_identifiers,
#     616     )
#
# File ~/.local/lib/python3.10/site-packages/snowflake/connector/cursor.py:1142, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1138     is_integrity_error = (
#    1139         code == "100072"
#    1140     )  # NULL result in a non-nullable column
#    1141     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1142     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1143 return self
#
# File ~/.local/lib/python3.10/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)
#     280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)
#     295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File ~/.local/lib/python3.10/site-packages/snowflake/connector/errors.py:354, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     352 cursor.messages.append((error_class, error_value))
#     353 try:
# --> 354     cursor.errorhandler(connection, cursor, error_class, error_value)
#     355 except NotImplementedError:
#     356     # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     357     cursor._errorhandler(connection, cursor, error_class, error_value)
#
# File ~/.local/lib/python3.10/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# ProgrammingError: 001003 (42000): SQL compilation error:
# syntax error line 1 at position 93 unexpected ':'.

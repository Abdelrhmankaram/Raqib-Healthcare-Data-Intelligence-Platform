# %%
import pandas as pd
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector

# %%
df = pd.read_parquet('/home/youssef/Documents/Raqib/Data/Final data/lab_events.parquet')

conn = snowflake.connector.connect(
    account='OFNFMZZ-WH33726',
    user='YOUSSEF',
    password='youssef-dbt123',
    database='RAW',
    schema='PUBLIC',        
    warehouse='RAQIB_WH',
    role='RAQIB_ROLE'
)

write_pandas(conn, df, 'lab_events', auto_create_table=True, quote_identifiers=False)
# Out:
# (True,
#  1,
#  250000,
#  [('snowpark_temp_stage_ib9169hwer/file0.txt',
#    'LOADED',
#    250000,
#    250000,
#    1,
#    0,
#    None,
#    None,
#    None,
#    None)])
